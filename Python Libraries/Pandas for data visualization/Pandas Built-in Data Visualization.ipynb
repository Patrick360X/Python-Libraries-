# %%
import numpy as np
import pandas as pd
# %matplotlib inline

import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30,edgecolor='black')
# Out:
# <Axes: >

# %%
df1['B'].plot(kind='hist',bins=30,edgecolor='cyan')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['C'].plot.hist(bins=20,edgecolor='yellow')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.4)    #alpha is used for transparency of plotted data
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1.plot.line(y='C',figsize=(12,3))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='magma')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['A','B'])

# %%
df.head()
# Out:
#           A         B
# 0  1.849123 -1.072168
# 1 -0.122063 -0.210147
# 2 -0.336274 -0.397111
# 3  1.112530  1.108644
# 4  0.360433  1.071678

# %%
df.plot.hexbin(x='A',y='B',gridsize=25)
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
